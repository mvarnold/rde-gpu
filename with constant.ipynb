# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import skimage
from skimage import data
import subprocess
import shlex
import time
import progressbar
from shutil import copyfile
colors = ["#2078B5", "#FF7F0F", "#2CA12C", "#D72827", "#9467BE", "#8C574B",
            "#E478C2", "#808080", "#BCBE20", "#17BED0", "#AEC8E9", "#FFBC79", 
            "#98E08B", "#FF9896", "#C6B1D6", "#C59D94", "#F8B7D3", "#C8C8C8", 
           "#DCDC8E", "#9EDAE6"]

# %%
def write_kernel(a,c,alpha):

    kernel = open('kernels.cl','w+')
    f1 = open('kernel1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float a   = ')
    kernel.write(str(a))
    
    f2 = open('kernel2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float c   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel3.cl','r')
    for i in f3:
        kernel.write(i)
    
    kernel.write('    const float alpha =')
    
    f3.close()
    kernel.write(' '+str(alpha))
    
    f4 = open('kernel4.cl','r')
    for i in f4:
        kernel.write(i)
    
    
    f4.close()

    kernel.close()
    
    
    
def check_pattern():
    path = '/Users/Winston/test/gpudep-master/OUTPUT/'
    image = 'output_000003.bmp'

    im = Image.open(path+image)
    im.load()
    height, width = im.size

    data = np.array(im)
    hist = skimage.exposure.histogram(data)

    if hist[0][0] > 7000:
        return 'black'
    elif hist[0][255] > 7000:
        return 'white' 
    else:
        return 'pattern'
bar = progressbar.ProgressBar(redirect_stdout=True)
c_list = np.arange(0.01,2.1,0.05)
alpha_list = np.logspace(-3.5, 1, 10)
for alpha in range(len(alpha_list)):
    
    a_list = np.zeros(len(c_list))
    count = 0
    for c in c_list:  
        bar.update(((alpha)*len(c_list)+count+1)*100/(len(alpha_list)*len(a_list)))
        a = 4.0 
        write_kernel(a,c,alpha_list[alpha])
        subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
        code = 1
        power = 2
        while code:
            pattern = check_pattern()
            if pattern =='black':

                if a-2**power> 0:
                    a = a-2**power
                    write_kernel(a,c,alpha_list[alpha])
                    subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
                else:
                    power = power - 1
            elif pattern == 'white':

                a = a+2**power  
                power = power - 1
                write_kernel(a,c,alpha_list[alpha])
                subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
            elif pattern == 'pattern':
                print('pattern')
                print("a = %.7f, c = %.2f, alpha = %.5f" %(a,c,alpha_list[alpha]))
                subprocess.call(shlex.split('./gpudep -b -g 300 -f 1 -t 7056'))
                copyfile('/Users/Winston/test/gpudep-master/OUTPUT/output_000002.bmp', '/Users/Winston/test/gpudep-master/pattern_check/%.5f_%.5f_%.5f.bmp'%(a,c,alpha))
                code = 0
                a_list[count] = a
                count +=1
                

            if power == -21:
                code = 0
                a_list[count] = a
                count +=1
            
    plt.plot(c_list,a_list,'.-', color = colors[alpha],label="alpha = %.4f"%alpha_list[alpha])
    print(a_list)
    plt.legend(bbox_to_anchor= (1.3,1) )
plt.xlabel('c')
plt.ylabel('a')
plt.title(' b = 0.00001 d =0.002')
plt.show()
# Out:
#   0% (  0 of 100) |                                          | Elapsed Time: 0:00:00 ETA:  --:--:--//anaconda/lib/python3.5/site-packages/skimage/exposure/exposure.py:63: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   warn("This might be a color image. The histogram will be "
#  10% ( 10 of 100) |####                                        | Elapsed Time: 0:19:29 ETA: 3:05:47
# [  9.53674316e-07   9.53674316e-07   3.40595245e-02   4.61082458e-02
#    4.61168289e-02   4.61215973e-02   4.61235046e-02   4.61254120e-02
#    4.61263657e-02   4.61263657e-02   4.61273193e-02   4.61273193e-02
#    4.61273193e-02   4.61273193e-02   4.61282730e-02   4.61282730e-02
#    4.61282730e-02   4.61282730e-02   4.61282730e-02   4.61282730e-02
#    4.61282730e-02   4.61282730e-02   4.61282730e-02   4.61282730e-02
#    4.61282730e-02   4.61282730e-02   4.61282730e-02   4.61282730e-02
#    4.61282730e-02   4.61282730e-02   4.61282730e-02   4.61282730e-02
#    4.61282730e-02   4.61282730e-02   4.61282730e-02   4.61282730e-02
#    4.61282730e-02   4.61282730e-
#  93% ( 93 of 100) |########################################    | Elapsed Time: 3:20:09 ETA: 0:15:11
# pattern
# a = 0.1889658, c = 0.61, alpha = 10.00000
#  97% ( 97 of 100) |##########################################  | Elapsed Time: 3:29:47 ETA: 0:06:46
# pattern
# a = 0.5151958, c = 1.46, alpha = 10.00000
# 100% (100 of 100) |###########################################| Elapsed Time: 3:36:54 ETA:  0:00:00

# %% [markdown]
# changing dz from 0.04569 to 0.01569

# %%
def write_kernel(a,c,alpha):

    kernel = open('kernels.cl','w+')
    f1 = open('kernel1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float a   = ')
    kernel.write(str(a))
    
    f2 = open('kernel2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float c   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel3.cl','r')
    for i in f3:
        kernel.write(i)
    
    kernel.write('    const float alpha =')
    
    f3.close()
    kernel.write(' '+str(alpha))
    
    f4 = open('kernel4.cl','r')
    for i in f4:
        kernel.write(i)
    
    
    f4.close()

    kernel.close()
    
def write_kernel_2(a,c):
    '''here a = D_zn, c = D_rb'''
    kernel = open('kernels.cl','w+')
    f1 = open('kernel_1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float dz   = ')
    kernel.write(str(a))
    
    f2 = open('kernel_2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float dr   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel_3.cl','r')
    for i in f3:
        kernel.write(i)
    
    f3.close()

    kernel.close()
    
    
def check_pattern():
    path = '/Users/Winston/test/gpudep-master/OUTPUT/'
    image = 'output_000003.bmp'

    im = Image.open(path+image)
    im.load()
    height, width = im.size

    data = np.array(im)
    hist = skimage.exposure.histogram(data)

    if hist[0][0] > 7000:
        return 'black'
    elif hist[0][255] > 7000:
        return 'white' 
    else:
        return 'pattern'
bar = progressbar.ProgressBar(redirect_stdout=True)
c_list = np.arange(0.01,2.1,0.05)
alpha_list = np.logspace(-3.5, 1, 10)
for alpha in range(len(alpha_list)):
    
    a_list = np.zeros(len(c_list))
    count = 0
    for c in c_list:  
        bar.update(((alpha)*len(c_list)+count+1)*100/(len(alpha_list)*len(a_list)))
        a = 4.0 
        write_kernel(a,c,alpha_list[alpha])
        subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
        code = 1
        power = 2
        while code:
            pattern = check_pattern()
            if pattern =='black':

                if a-2**power> 0:
                    a = a-2**power
                    write_kernel(a,c,alpha_list[alpha])
                    subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
                else:
                    power = power - 1
            elif pattern == 'white':

                a = a+2**power  
                power = power - 1
                write_kernel(a,c,alpha_list[alpha])
                subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
            elif pattern == 'pattern':
                print('pattern')
                print("a = %.7f, c = %.2f, alpha = %.5f" %(a,c,alpha_list[alpha]))
                subprocess.call(shlex.split('./gpudep -b -g 300 -f 1 -t 7056'))
                copyfile('/Users/Winston/test/gpudep-master/OUTPUT/output_000002.bmp', '/Users/Winston/test/gpudep-master/pattern_check/%.5f_%.5f_%.5f.bmp'%(a,c,alpha))
                code = 0
                a_list[count] = a
                count +=1
                

            if power == -21:
                code = 0
                a_list[count] = a
                count +=1
            
    plt.plot(c_list,a_list,'.-', color = colors[alpha],label="alpha = %.4f"%alpha_list[alpha])
    print(a_list)
    plt.legend(bbox_to_anchor= (1.3,1) )
plt.xlabel('c')
plt.ylabel('a')
plt.title(' b = 0.00001 d =0.002')
plt.show()
# Out:
#   0% (  0 of 100) |                                          | Elapsed Time: 0:00:00 ETA:  --:--:--//anaconda/lib/python3.5/site-packages/skimage/exposure/exposure.py:63: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   warn("This might be a color image. The histogram will be "
# 100% (100 of 100) |###########################################| Elapsed Time: 4:28:40 ETA:  0:00:00

# %%
'''for changing dr and dz'''

def write_kernel(a,c,alpha):

    kernel = open('kernels.cl','w+')
    f1 = open('kernel1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float a   = ')
    kernel.write(str(a))
    
    f2 = open('kernel2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float c   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel3.cl','r')
    for i in f3:
        kernel.write(i)
    
    kernel.write('    const float alpha =')
    
    f3.close()
    kernel.write(' '+str(alpha))
    
    f4 = open('kernel4.cl','r')
    for i in f4:
        kernel.write(i)
    
    
    f4.close()

    kernel.close()
    
def write_kernel_2(a,c,alpha):
    '''here a = D_zn, c = D_rb'''
    kernel = open('kernels.cl','w+')
    f1 = open('kernel_1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float dz   = ')
    kernel.write(str(a))
    
    f2 = open('kernel_2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float dr   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel_3.cl','r')
    for i in f3:
        kernel.write(i)
    
    f3.close()

    kernel.close()
    
    
def check_pattern():
    path = '/Users/Winston/test/gpudep-master/OUTPUT/'
    image = 'output_000003.bmp'

    im = Image.open(path+image)
    im.load()
    height, width = im.size

    data = np.array(im)
    hist = skimage.exposure.histogram(data)

    if hist[0][0] > 7000:
        return 'black'
    elif hist[0][255] > 7000:
        return 'white' 
    else:
        return 'pattern'
bar = progressbar.ProgressBar(redirect_stdout=True)
c_list = np.logspace(-4,1,40)
alpha_list = np.logspace(-3.5, 1, 1)
for alpha in range(len(alpha_list)):
    
    a_list = np.zeros(len(c_list))
    count = 0
    for c in c_list:  
        bar.update(((alpha)*len(c_list)+count+1)*100/(len(alpha_list)*len(a_list)))
        a = 16.0 
        write_kernel_2(a,c,alpha_list[alpha])
        subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
        code = 1
        power = 4
        while code:
            pattern = check_pattern()
            if pattern =='black':

                if a-2**power> 0:
                    a = a-2**power
                    write_kernel_2(a,c,alpha_list[alpha])
                    subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
                else:
                    power = power - 1
            elif pattern == 'white':

                a = a+2**power  
                power = power - 1
                write_kernel(a,c,alpha_list[alpha])
                subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
            elif pattern == 'pattern':
                print('pattern')
                print("a = %.7f, c = %.2f, alpha = %.5f" %(a,c,alpha_list[alpha]))
                subprocess.call(shlex.split('./gpudep -b -g 300 -f 1 -t 7056'))
                copyfile('/Users/Winston/test/gpudep-master/OUTPUT/output_000002.bmp', '/Users/Winston/test/gpudep-master/pattern_check/%.5f_%.5f_%.5f.bmp'%(a,c,alpha))
                code = 0
                a_list[count] = a
                count +=1
                

            if power == -21:
                code = 0
                a_list[count] = a
                count +=1
            
    plt.plot(c_list,a_list,'.-', color = colors[alpha],label="alpha = %.4f"%alpha_list[alpha])
    print(a_list)
    plt.legend(bbox_to_anchor= (1.3,1) )
plt.xlabel('c (D_rb)')
plt.ylabel('a (D_zn)')
plt.title(' b = 0.00001 d =0.002')
plt.show()
# Out:
#   2% (  2 of 100) |#                                          | Elapsed Time: 0:00:00 ETA:  0:00:00//anaconda/lib/python3.5/site-packages/skimage/exposure/exposure.py:63: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   warn("This might be a color image. The histogram will be "
# 100% (100 of 100) |###########################################| Elapsed Time: 0:20:42 ETA:  0:00:00

# %%
'''for changing dr and dz'''

def write_kernel(a,c,alpha):

    kernel = open('kernels.cl','w+')
    f1 = open('kernel1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float a   = ')
    kernel.write(str(a))
    
    f2 = open('kernel2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float c   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel3.cl','r')
    for i in f3:
        kernel.write(i)
    
    kernel.write('    const float alpha =')
    
    f3.close()
    kernel.write(' '+str(alpha))
    
    f4 = open('kernel4.cl','r')
    for i in f4:
        kernel.write(i)
    
    
    f4.close()

    kernel.close()
    
def write_kernel_2(a,c,alpha):
    '''here a = D_zn, c = D_rb'''
    kernel = open('kernels.cl','w+')
    f1 = open('kernel_1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float dz   = ')
    kernel.write(str(a))
    
    f2 = open('kernel_2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float dr   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel_3.cl','r')
    for i in f3:
        kernel.write(i)
    
    f3.close()

    kernel.close()
    
    
def check_pattern():
    path = '/Users/Winston/test/gpudep-master/OUTPUT/'
    image = 'output_000003.bmp'

    im = Image.open(path+image)
    im.load()
    height, width = im.size

    data = np.array(im)
    hist = skimage.exposure.histogram(data)

    if hist[0][0] > 7000:
        return 'black'
    elif hist[0][255] > 7000:
        return 'white' 
    else:
        return 'pattern'
bar = progressbar.ProgressBar(redirect_stdout=True)
c_list = np.logspace(-4,1,40)
alpha_list = np.logspace(-3.5, 1, 1)
for alpha in range(len(alpha_list)):
    
    a_list = np.zeros(len(c_list))
    count = 0
    for c in c_list:  
        bar.update(((alpha)*len(c_list)+count+1)*100/(len(alpha_list)*len(a_list)))
        a = 16.0 
        write_kernel_2(a,c,alpha_list[alpha])
        subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
        code = 1
        power = 4
        while code:
            pattern = check_pattern()
            if pattern =='black':

                if a-2**power> 0:
                    a = a-2**power
                    write_kernel_2(a,c,alpha_list[alpha])
                    subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
                else:
                    power = power - 1
            elif pattern == 'white':

                a = a+2**power  
                power = power - 1
                write_kernel(a,c,alpha_list[alpha])
                subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
            elif pattern == 'pattern':
                print('pattern')
                print("a = %.7f, c = %.2f, alpha = %.5f" %(a,c,alpha_list[alpha]))
                subprocess.call(shlex.split('./gpudep -b -g 300 -f 1 -t 7056'))
                copyfile('/Users/Winston/test/gpudep-master/OUTPUT/output_000002.bmp', '/Users/Winston/test/gpudep-master/pattern_check/%.5f_%.5f_%.5f.bmp'%(a,c,alpha))
                code = 0
                a_list[count] = a
                count +=1
                

            if power == -21:
                code = 0
                a_list[count] = a
                count +=1
            
    plt.plot(c_list,a_list,'.-', color = colors[alpha],label="alpha = %.4f"%alpha_list[alpha])
    print(a_list)
    plt.legend(bbox_to_anchor= (1.3,1) )
plt.xlabel('c (D_rb)')
plt.ylabel('a (D_zn)')
plt.title(' b = 0.00001 d =0.002')
plt.show()
# Out:
#   2% (  2 of 100) |#                                          | Elapsed Time: 0:00:00 ETA:  0:00:00//anaconda/lib/python3.5/site-packages/skimage/exposure/exposure.py:63: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   warn("This might be a color image. The histogram will be "
# 100% (100 of 100) |###########################################| Elapsed Time: 0:20:53 ETA:  0:00:00

# %%
'''for changing dr and dz'''

def write_kernel(a,c,alpha):

    kernel = open('kernels.cl','w+')
    f1 = open('kernel1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float a   = ')
    kernel.write(str(a))
    
    f2 = open('kernel2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float c   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel3.cl','r')
    for i in f3:
        kernel.write(i)
    
    kernel.write('    const float alpha =')
    
    f3.close()
    kernel.write(' '+str(alpha))
    
    f4 = open('kernel4.cl','r')
    for i in f4:
        kernel.write(i)
    
    
    f4.close()

    kernel.close()
    
def write_kernel_2(a,c,alpha):
    '''here a = D_zn, c = D_rb'''
    kernel = open('kernels.cl','w+')
    f1 = open('kernel_1.cl','r')
    for i in f1:
        kernel.write(i)

    f1.close()
    kernel.write('    const float dz   = ')
    kernel.write(str(a))
    
    f2 = open('kernel_2.cl','r')
    for i in f2:
        kernel.write(i)
    
    f2.close()
    kernel.write('    const float dr   =')
    kernel.write(' '+str(c))
    
    f3 = open('kernel_3.cl','r')
    for i in f3:
        kernel.write(i)
    
    f3.close()

    kernel.close()
    
    
def check_pattern():
    path = '/Users/Winston/test/gpudep-master/OUTPUT/'
    image = 'output_000003.bmp'

    im = Image.open(path+image)
    im.load()
    height, width = im.size

    data = np.array(im)
    hist = skimage.exposure.histogram(data)

    if hist[0][0] > 7000:
        return 'black'
    elif hist[0][255] > 7000:
        return 'white' 
    else:
        return 'pattern'
bar = progressbar.ProgressBar(redirect_stdout=True)
c_list = np.logspace(-4,1,40)
alpha_list = np.logspace(-3.5, 1, 1)
for alpha in range(len(alpha_list)):
    
    a_list = np.zeros(len(c_list))
    count = 0
    for c in c_list:  
        bar.update(((alpha)*len(c_list)+count+1)*100/(len(alpha_list)*len(a_list)))
        a = 16.0 
        write_kernel_2(a,c,alpha_list[alpha])
        subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
        code = 1
        power = 4
        while code:
            pattern = check_pattern()
            if pattern =='black':

                if a-2**power> 0:
                    a = a-2**power
                    write_kernel_2(a,c,alpha_list[alpha])
                    subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
                else:
                    power = power - 1
            elif pattern == 'white':

                a = a+2**power  
                power = power - 1
                write_kernel(a,c,alpha_list[alpha])
                subprocess.call(shlex.split('./gpudep -b -g 50 -f 1 -t 7056'))
            elif pattern == 'pattern':
                print('pattern')
                print("a = %.7f, c = %.2f, alpha = %.5f" %(a,c,alpha_list[alpha]))
                subprocess.call(shlex.split('./gpudep -b -g 300 -f 1 -t 7056'))
                copyfile('/Users/Winston/test/gpudep-master/OUTPUT/output_000002.bmp', '/Users/Winston/test/gpudep-master/pattern_check/%.5f_%.5f_%.5f.bmp'%(a,c,alpha))
                code = 0
                a_list[count] = a
                count +=1
                

            if power == -21:
                code = 0
                a_list[count] = a
                count +=1
            
    plt.plot(c_list,a_list,'.-', color = colors[alpha],label="alpha = %.4f"%alpha_list[alpha])
    print(a_list)
    plt.legend(bbox_to_anchor= (1.3,1) )
plt.xlabel('c (D_rb)')
plt.ylabel('a (D_zn)')
plt.title(' b = 0.00001 d =0.002')
plt.show()
# Out:
#   2% (  2 of 100) |#                                          | Elapsed Time: 0:00:00 ETA:  0:00:00//anaconda/lib/python3.5/site-packages/skimage/exposure/exposure.py:63: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   warn("This might be a color image. The histogram will be "
# 100% (100 of 100) |###########################################| Elapsed Time: 0:20:59 ETA:  0:00:00
